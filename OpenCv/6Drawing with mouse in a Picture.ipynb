# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

#########Function######

def draw_circle(event, x,y,flags,param):
#event = what the mouse actually did whether right click or left click or ...scroll
#x & y = basically taken automatically by the openCV (x position and y position of the mouse callback)
#flags & params = these are passed back in case there's additional parameters or some warning flags necessary
    if event == cv2.EVENT_LBUTTONDOWN:
        # so if the event happens, an circle is drawn in the img wrt x & y mouse position callback
        cv2.circle(img,(x,y),radius = 50,color= (255,0,0),thickness = -1)
        
#naming the window
cv2.namedWindow(winname="my_drawing")

#connecting to the callback
cv2.setMouseCallback("my_drawing",draw_circle)






#####Showing image with OpenCV######

#1-assigning image
img = np.zeros((512,512,3),dtype=np.int8)

while True:
    #pass in the img image
    cv2.imshow("my_drawing",img)
    
    #waitkey (20ms) wait  & 0xFF ==27 ..
    #So, if someone hits the escape button once it will wait for 20ms and someone hit the escape button again
    #it will break the loop
    
    if cv2.waitKey(20) & 0xFF ==27:
        break
#this destroy the working window
cv2.destroyAllWindows()

# %% [markdown]
# # Gist of above:
#
# #showing image with opencv
# 1. assigning an image
# 2. then passing the created image and assinging a condition to show the image
# 3. creating a condition to break the event happening in the window
#
# 1. Naming the window
# 2. assigning the callback in mouse and passing the function along with the img("my_drawing)
# #function
# 1. creating a function with the parameters
#     - x & y coordinates of that event with mouse
#     - then checking the particular event occurred
#     - if True: going head and drawing the image by passing the img.

# %% [markdown]
# # Doing with multiple events

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

#########Function######

def draw_circle(event, x,y,flags,param):
#event = what the mouse actually did whether right click or left click or ...scroll
#x & y = basically taken automatically by the openCV (x position and y position of the mouse callback)
#flags & params = these are passed back in case there's additional parameters or some warning flags necessary
   
    if event == cv2.EVENT_LBUTTONDOWN:
        # so if the event happens, an circle is drawn in the img wrt x & y mouse position callback
        cv2.circle(img,(x,y),radius = 50,color= (255,0,0),thickness = -1)
    elif event == cv2.EVENT_MOUSEMOVE:
        cv2.circle(img,(x,y),radius = 50,color= (0,255,0),thickness = -1)
   
        
#naming the window
cv2.namedWindow(winname="my_drawing")

#connecting to the callback
cv2.setMouseCallback("my_drawing",draw_circle)






#####Showing image with OpenCV######

#1-assigning image
img = np.zeros((512,512,3),dtype=np.int8)

while True:
    #pass in the img image
    cv2.imshow("my_drawing",img)
    
    #waitkey (20ms) wait  & 0xFF ==27 ..
    #So, if someone hits the escape button once it will wait for 20ms and someone hit the escape button again
    #it will break the loop
    
    if cv2.waitKey(20) & 0xFF ==27:
        break
#this destroy the working window
cv2.destroyAllWindows()

# %% [markdown]
# # Drawing a rectangle using mouse

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

#VARIABLES#

# this drawing is the mouse, if the mouse is pressed and turns True and keep as true and continue drawing
# Basically, True while mouse button is Down and False while mouse button is Up
drawing = False
ix = -1
iy = -1

#ix and iy are the actual point where the mouse button is down 

# Function to draw rectangle#

def draw_rectangle (event,x,y,flags,param):
    global ix,iy,drawing
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix,iy = x,y
    #If the mouse is keepon moving 
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing == True:
            cv2.rectangle(img1,(ix,iy),(x,y),(0,255,0),-1)
    #if the button is up .. completing by drawing a final rectangle
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        cv2.rectangle(img1,(ix,iy),(x,y),(255,0,0), -1)
        
 


    #### Showing the image using OpenCV####

img1 = np.zeros((512,512,3))
cv2.namedWindow(winname="my_drawing")
cv2.setMouseCallback("my_drawing",draw_rectangle)

while True:
    #to connect the drawing and img1
    cv2.imshow("my_drawing",img1)
    
    if cv2.waitKey(1) & 0xFF ==27:
        break
#this destroy the working window
cv2.destroyAllWindows()
